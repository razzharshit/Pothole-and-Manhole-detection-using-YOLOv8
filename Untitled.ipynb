# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# PyTorch version: 2.5.1+cu121
# CUDA available: True
# CUDA version: 12.1

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU available")
# Out:
# 2.5.1+cu121
# True
# NVIDIA GeForce GTX 1650

# %%
# %matplotlib inline

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce GTX 1650
# Using device: cuda

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import os

folder_name = 'dataset/train/images'

absolute_path = os.path.abspath(folder_name)
print(f"Absolute path: {absolute_path}")
# Out:
# Absolute path: C:\Users\rajha\Downloads\archive (1)\dataset\train\images

# %%
import os

image_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\images'
label_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\labels'
# List the image and label files
image_files = os.listdir(image_folder)
label_files = os.listdir(label_folder)

# Count the current number of images and labels
num_images = len(image_files)
num_labels = len(label_files)

num_images, num_labels
# Out:
# (481, 481)

# %%
from PIL import Image
import os

# Define the folder containing the images
image_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\images'

# List all .png files in the folder
png_files = [f for f in os.listdir(image_folder) if f.endswith('.png')]

# Convert each .png to .jpg
for png_file in png_files:
    # Construct full file path
    png_path = os.path.join(image_folder, png_file)
    jpg_path = os.path.join(image_folder, os.path.splitext(png_file)[0] + '.jpg')

    # Open the .png image and convert it to .jpg
    with Image.open(png_path) as img:
        rgb_img = img.convert('RGB')  # Ensure the image is in RGB mode
        rgb_img.save(jpg_path, 'JPEG')

    # Optionally, delete the original .png file
    os.remove(png_path)
    print(f"Converted {png_file} to {os.path.basename(jpg_path)} and deleted the original.")

print("Conversion completed successfully.")
# Out:
# Conversion completed successfully.

# %%
import os

# Define paths for images and labels
image_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\images'
label_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\labels'

# List the image and label files (filter by extensions)
image_files = [f for f in os.listdir(image_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]
label_files = [f for f in os.listdir(label_folder) if f.endswith('.txt')]

# Extract base names without extensions for comparison
image_basenames = {os.path.splitext(file)[0] for file in image_files}
label_basenames = {os.path.splitext(file)[0] for file in label_files}

# Find the images that don't have corresponding labels
unmatched_images = image_basenames - label_basenames

# Delete unmatched images
for image_name in unmatched_images:
    # Construct the full file path
    for extension in ['.jpg', '.png', '.jpeg']:
        image_path = os.path.join(image_folder, image_name + extension)
        if os.path.exists(image_path):
            os.remove(image_path)
            print(f"Deleted unmatched image: {image_path}")

# Print completion message
print("Unmatched images deleted successfully.")
# Out:
# Unmatched images deleted successfully.

# %%
import os

# Define paths to the folders for each category
pothole_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\pothole\images'
crack_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\images'
open_manhole_folder = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\open_manhole\images'

# Function to count image files in a folder
def count_images(folder, extensions=('.jpg', '.jpeg', '.png')):
    return len([f for f in os.listdir(folder) if f.endswith(extensions)])

# Count images in each category
pothole_count = count_images(pothole_folder)
crack_count = count_images(crack_folder)
open_manhole_count = count_images(open_manhole_folder)

# Output results
print(f"Number of pothole images: {pothole_count}")
print(f"Number of crack images: {crack_count}")
print(f"Number of open manhole images: {open_manhole_count}")

# Total count
total_images = pothole_count + crack_count + open_manhole_count
print(f"Total number of images: {total_images}")
# Out:
# Number of pothole images: 300
# Number of crack images: 166
# Number of open manhole images: 152
# Total number of images: 618

# %%
import os
import cv2
import albumentations as A
from tqdm import tqdm

# Local paths
images_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\images'
labels_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\labels'
output_images_path = r'C:\Users\rajha\Downloads\augmented\images'
output_labels_path = r'C:\Users\rajha\Downloads\augmented\labels'

# Create output directories if they don't exist
os.makedirs(output_images_path, exist_ok=True)
os.makedirs(output_labels_path, exist_ok=True)

# Augmentation pipeline
augment = A.Compose([
    A.Rotate(limit=30, border_mode=0, p=1.0),
    A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=1.0),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids']))

# Get valid image-label file pairs
image_files = sorted([f for f in os.listdir(images_path) if f.endswith(('.jpg', '.png'))])
label_files = sorted([f for f in os.listdir(labels_path) if f.endswith('.txt')])

# Ensure matching filenames
paired_files = [(img, img.replace('.jpg', '.txt').replace('.png', '.txt')) 
                for img in image_files if img.replace('.jpg', '.txt').replace('.png', '.txt') in label_files]

current_image_count = len(paired_files)
target_image_count = 500
new_image_id = current_image_count + 1

for image_file, label_file in tqdm(paired_files):
    if current_image_count >= target_image_count:
        break

    image_path = os.path.join(images_path, image_file)
    label_path = os.path.join(labels_path, label_file)
    image = cv2.imread(image_path)

    if image is None:
        print(f"Skipping invalid image: {image_file}")
        continue

    # Read labels
    bboxes = []
    category_ids = []
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) != 5:
                print(f"Skipping invalid line in {label_file}: {line}")
                continue
            try:
                class_id, x_center, y_center, width, height = map(float, parts)
                bboxes.append([x_center, y_center, width, height])
                category_ids.append(int(class_id))
            except ValueError:
                print(f"Corrupt values in {label_file}: {line}")
                continue

    if not bboxes:
        continue

    # Apply augmentation
    augmented = augment(image=image, bboxes=bboxes, category_ids=category_ids)

    # Save image and label
    new_img_name = f'{new_image_id:04}.jpg'
    cv2.imwrite(os.path.join(output_images_path, new_img_name), augmented['image'])

    new_lbl_name = f'{new_image_id:04}.txt'
    with open(os.path.join(output_labels_path, new_lbl_name), 'w') as f:
        for bbox, category_id in zip(augmented['bboxes'], augmented['category_ids']):
            f.write(f"{category_id} {' '.join(map(str, bbox))}\n")

    new_image_id += 1
    current_image_count += 1

print(f"✅ Augmentation completed! Total images: {current_image_count}")
# Out:
# 0it [00:00, ?it/s]
# ✅ Augmentation completed! Total images: 0

# %%
import os
import cv2
import albumentations as A
from tqdm import tqdm

# Paths
images_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\images'
labels_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\labels'
output_images_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\augmented\images'
output_labels_path = r'C:\Users\rajha\Downloads\archive (1)\dataset\dataset\classes\cracks\augmented\labels'

# Create output directories
os.makedirs(output_images_path, exist_ok=True)
os.makedirs(output_labels_path, exist_ok=True)

# Augmentations
augmentations = {
    "rotate": A.Compose([A.Rotate(limit=30, border_mode=0, p=1.0)], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids'])),
    "hflip": A.Compose([A.HorizontalFlip(p=1.0)], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids'])),
    "vflip": A.Compose([A.VerticalFlip(p=1.0)], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids'])),
    "brightness": A.Compose([A.RandomBrightnessContrast(brightness_limit=0.3, contrast_limit=0.3, p=1.0)], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids'])),
}

# Files
label_files = sorted([f for f in os.listdir(labels_path) if f.endswith('.txt') and os.path.isfile(os.path.join(labels_path, f))])
image_files = sorted([f for f in os.listdir(images_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])


current_image_count = 667
max_image_count = 1000
new_image_id = current_image_count

for image_file, label_file in tqdm(zip(image_files, label_files), total=len(image_files)):
    if new_image_id > max_image_count:
        break

    image_path = os.path.join(images_path, image_file)
    label_path = os.path.join(labels_path, label_file)
    image = cv2.imread(image_path)

    # Read YOLO labels
    with open(label_path, 'r') as f:
        lines = f.readlines()

    bboxes = []
    category_ids = []
    for line in lines:
        try:
            class_id, x_center, y_center, width, height = map(float, line.strip().split())
            bboxes.append([x_center, y_center, width, height])
            category_ids.append(int(class_id))
        except ValueError:
            print(f"Invalid line in {label_file}: {line}")
            continue

    if not bboxes:
        continue

    for name, augmenter in augmentations.items():
        if new_image_id > max_image_count:
            break

        augmented = augmenter(image=image, bboxes=bboxes, category_ids=category_ids)

        # Save image
        new_img_name = f'{new_image_id:04}.jpg'
        cv2.imwrite(os.path.join(output_images_path, new_img_name), augmented['image'])

        # Save label
        new_lbl_name = f'{new_image_id:04}.txt'
        with open(os.path.join(output_labels_path, new_lbl_name), 'w') as f:
            for bbox, category_id in zip(augmented['bboxes'], augmented['category_ids']):
                f.write(f"{category_id} {' '.join(map(str, bbox))}\n")

        new_image_id += 1

print(f"✅ Augmentation completed! Total new images: {new_image_id - current_image_count}")
# Out:
#   0%|          | 0/166 [00:00<?, ?it/s]
# ✅ Augmentation completed! Total new images: 0

# %%
# %cd C:\Users\rajha\Downloads\archive (1)\dataset\dataset
# Out:
# C:\Users\rajha\Downloads\archive (1)\dataset\dataset

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 68B7-69C8
#
#  Directory of C:\Users\rajha\Downloads\archive (1)
#
# 06-05-2025  13:57    <DIR>          .
# 29-05-2025  01:14    <DIR>          ..
# 05-05-2025  00:44    <DIR>          .ipynb_checkpoints
# 17-03-2025  19:41    <DIR>          dataset
# 06-05-2025  13:51         8,325,831 potholedetectionpc.ipynb
# 05-05-2025  00:32                74 test.py
# 23-02-2025  19:47         1,334,779 train_annotations1.json
# 06-05-2025  13:57            19,445 Untitled.ipynb
# 23-02-2025  19:47           359,934 valid_annotations1.json
#                5 File(s)     10,040,063 bytes
#                4 Dir(s)  282,080,604,160 bytes free

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load pre-trained model
model.train(data=r"C:\Users\rajha\Downloads\archive (1)\dataset\dataset\data.yaml", epochs=50, workers=4)
 # start training
# Out:
# Ultralytics 8.3.146  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
pip install matplotlib seaborn
# Out:
# ...
#
# ...

# %%
from ultralytics.utils.plotting import plot_results

# Path to your results.csv file
csv_path = r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train3\results.csv"

# This will generate the plots in the same directory
plot_results(file=csv_path)

# %%
import pandas as pd

csv_path = r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train3\results.csv"
df = pd.read_csv(csv_path)
print(df.head())
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1  79.7761         1.72629          2.7575         1.74778
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.39018             0.3232           0.33061
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.14222         2.008       3.28393       2.08386  0.000414
#
#      lr/pg1    lr/pg2
# 0  0.000414  0.000414

# %%
from IPython.display import Image

# Now display the image
Image(filename=r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\results.png", width=600)

# %%
Image(filename=r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\F1_curve.png", width=600)

# %%
Image(filename=r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\P_curve.png", width=600)

# %%
Image(filename=r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\confusion_matrix.png", width=600)

# %%
from ultralytics import YOLO

model = YOLO(r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt")

results = model.val(data=r"C:\Users\rajha\Downloads\archive (1)\dataset\dataset\data.yaml", batch=1)

print(results)
# Out:
# Ultralytics 8.3.146  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.1 ms, read: 219.4139.8 MB/s, size: 119.2 KB)
# val: Scanning C:\Users\rajha\Downloads\archive (1)\dataset\dataset\valid\labels.cache... 480 images, 0 backgrounds, 0 corrupt: 100%|██████████| 480/480 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 480/480 [00:10<00:00, 45.56it/s]
#                    all        480        743       0.84      0.722      0.782      0.376
#                 cracks        182        425      0.823      0.522      0.668      0.316
#              good_road        155        170      0.805      0.724       0.76      0.326
#           open_manhole        148        148      0.891      0.919      0.917      0.486
# ...

# %%
# !yolo task=detect mode=predict model="C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt" conf=0.25 source="C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images"
# Out:
# Ultralytics 8.3.146  Python-3.12.7 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/20 C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images\1000_F_256252609_6WIHRGbpzSaVQwioubxwgXdSJTNONNcK.jpg: 288x640 1 good_road, 53.9ms
# image 2/20 C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images\360_F_916445076_KAGVDE2nuHOIxNARmepMJTgHQqd9Y7y0.jpg: 320x640 2 crackss, 29.8ms
# image 3/20 C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images\DSC00004.jpg: 480x640 (no detections), 44.6ms
# image 4/20 C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images\closemahole1.jpg: 448x640 (no detections), 35.2ms
# image 5/20 C:\Users\rajha\Downloads\archive (1)\dataset\dataset\test\images\cracking-(1).jpg: 480x640 (no detections), 11.8ms
# ...

# %%
import math

num_images = len(predicted_images)
cols = 5  # number of images per row
rows = math.ceil(num_images / cols)

fig, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 4))

# Flatten axes in case of multiple rows
axes = axes.flatten() if num_images > 1 else [axes]

for i in range(len(axes)):
    axes[i].axis('off')  # hide axes for all subplots initially

for i, image_path in enumerate(predicted_images):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    axes[i].imshow(image)
    axes[i].axis('off')
    axes[i].set_title(f"Image {i+1}")

plt.tight_layout()
plt.show()

# %%
import os
import cv2
import matplotlib.pyplot as plt

results_path = "runs/detect/predict"

# Get list of images
predicted_images = sorted(
    [os.path.join(results_path, img) for img in os.listdir(results_path) if img.lower().endswith(('.jpg', '.png'))]
)

print(f"Found {len(predicted_images)} images")

# Limit max number of images to display (e.g. 10) to avoid huge figures
max_images = 10
images_to_show = predicted_images[:max_images]

# Create subplots with one row, len(images_to_show) columns
fig, axes = plt.subplots(1, len(images_to_show), figsize=(20, 5))

# If only one image, axes is not a list, make it a list for uniformity
if len(images_to_show) == 1:
    axes = [axes]

for ax, img_path in zip(axes, images_to_show):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(os.path.basename(img_path))

plt.tight_layout()
plt.show()
# Out:
# Found 19 images

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Path to your local image file
image_path = r"C:\Users\rajha\Downloads\potholes-on-rural-road-nr-hobhouse-free-state-south-africa-C452BB.jpg"  # replace with your image path

# Load the trained YOLOv8 model (local path)
model = YOLO(r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt")

# Perform prediction on the image
results = model(image_path)

# Extract image with bounding boxes drawn
img_with_boxes = results[0].plot()

# Display using matplotlib
plt.imshow(img_with_boxes)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\rajha\Downloads\potholes-on-rural-road-nr-hobhouse-free-state-south-africa-C452BB.jpg: 640x416 2 crackss, 82.8ms
# Speed: 25.9ms preprocess, 82.8ms inference, 48.8ms postprocess per image at shape (1, 3, 640, 416)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Path to your local image file
image_path = r"C:\Users\rajha\Downloads\OIP (4).jpeg"  # replace with your image path

# Load the trained YOLOv8 model (local path)
model = YOLO(r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt")

# Perform prediction on the image
results = model(image_path)

# Extract image with bounding boxes drawn
img_with_boxes = results[0].plot()

# Display using matplotlib
plt.imshow(img_with_boxes)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\rajha\Downloads\OIP (4).jpeg: 608x640 1 good_road, 74.9ms
# Speed: 8.2ms preprocess, 74.9ms inference, 25.2ms postprocess per image at shape (1, 3, 608, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Path to your local image file
image_path = r"C:\Users\rajha\Downloads\OIP (5).jpeg"  # replace with your image path

# Load the trained YOLOv8 model (local path)
model = YOLO(r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt")

# Perform prediction on the image
results = model(image_path)

# Extract image with bounding boxes drawn
img_with_boxes = results[0].plot()

# Display using matplotlib
plt.imshow(img_with_boxes)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\rajha\Downloads\OIP (5).jpeg: 480x640 1 open_manhole, 62.1ms
# Speed: 9.3ms preprocess, 62.1ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Path to your local image file
image_path = r"C:\Users\rajha\Downloads\OIP (11).jpeg"  # replace with your image path

# Load the trained YOLOv8 model (local path)
model = YOLO(r"C:\Users\rajha\Downloads\archive (1)\runs\detect\train7\weights\best.pt")

# Perform prediction on the image
results = model(image_path)

# Extract image with bounding boxes drawn
img_with_boxes = results[0].plot()

# Display using matplotlib
plt.imshow(img_with_boxes)
plt.axis('off')
plt.show()
# Out:
# image 1/1 C:\Users\rajha\Downloads\OIP (11).jpeg: 480x640 1 open_manhole, 70.8ms
# Speed: 9.3ms preprocess, 70.8ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
